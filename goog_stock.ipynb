# %%
# Styling notebook
from IPython.core.display import HTML
css_file= """
<style>
div.input_area {
    background-color: #F1F0F0; /* gray */
    border-top: 2px solid #000000; /* black */
}

@import url('https://fonts.googleapis.com/css?family=Quicksand&display=swap');
 * {
    margin: 0;
    padding: 0;
    box-sizing: border-box;
}

 .alert {
    width: 80%;
    margin: 20px auto;
    padding: 30px;
    position: relative;
    border-radius: 5px;
    box-shadow: 0 0 15px 5px #ccc;
}
 .close {
    position: absolute;
    width: 30px;
    height: 30px;
    opacity: 0.5;
    border-width: 1px;
    border-style: solid;
    border-radius: 50%;
    right: 15px;
    top: 25px;
    text-align: center;
    font-size: 1.6em;
    cursor: pointer;
}
 .simple-alert {
    background-color: #aed6e5;
    border-left: 5px solid #245b70;
}
 .simple-alert .close {
    border-color: #245b70;
    color: #245b70;
}
 .success-alert {
    background-color: #aee5c0;
    border-left: 5px solid #24703d;
}
 .success-alert .close {
    border-color: #24703d;
    color: #24703d;
}
 .danger-alert {
    background-color: #e5aeae;
    border-left: 5px solid #702424;
}
 .danger-alert .close {
    border-color: #702424;
    color: #702424;
}
 .warning-alert {
    background-color: #ffe6a9;
    border-left: 5px solid #a97800;
}
 .warning-alert .close {
    border-color: #a97800;
    color: #a97800;
}

li {
  list-style: none; /* Remove default bullets */
}

ul li::before {
  content: "•";
  color: #B41B10;
  font-weight: bold;
  display: inline-block; /* Needed to add space between the bullet and the text */
  width: 1em; /* Also needed for space (tweak if needed) */
  margin-left: -1em; /* Also needed for space (tweak if needed) */
  font-size:120%;
}

.number{
    color:#B41B10;
}

mark {
 background-color:#D59A99;
 color:#B41B10;
 border-radius: 6px;
 padding: 2px 5px;
}

.btn {
  background-color: gray;
  border: none;
  color: white !important;
  padding: 5px 15px;
  font-size: 18px;
  cursor: pointer;
}

/* Darker background on mouse-over */
.btn:hover {
  background-color: Red;
}

</style>
"""
HTML(css_file)
# Out:
# <style>
# div.input_area {
#     background-color: #F1F0F0; /* gray */
#     border-top: 2px solid #000000; /* black */
# }
#
# @import url('https://fonts.googleapis.com/css?family=Quicksand&display=swap');
#  * {
#     margin: 0;
#     padding: 0;
#     box-sizing: border-box;
# }
#
#  .alert {
#     width: 80%;
#     margin: 20px auto;
#     padding: 30px;
#     position: relative;
#     border-radius: 5px;
#     box-shadow: 0 0 15px 5px #ccc;
# }
#  .close {
#     position: absolute;
#     width: 30px;
#     height: 30px;
#     opacity: 0.5;
#     border-width: 1px;
#     border-style: solid;
#     border-radius: 50%;
#     right: 15px;
#     top: 25px;
#     text-align: center;
#     font-size: 1.6em;
#     cursor: pointer;
# }
#  .simple-alert {
#     background-color: #aed6e5;
#     border-left: 5px solid #245b70;
# }
#  .simple-alert .close {
#     border-color: #245b70;
#     color: #245b70;
# }
#  .success-alert {
#     background-color: #aee5c0;
#     border-left: 5px solid #24703d;
# }
#  .success-alert .close {
#     border-color: #24703d;
#     color: #24703d;
# }
#  .danger-alert {
#     background-color: #e5aeae;
#     border-left: 5px solid #702424;
# }
#  .danger-alert .close {
#     border-color: #702424;
#     color: #702424;
# }
#  .warning-alert {
#     background-color: #ffe6a9;
#     border-left: 5px solid #a97800;
# }
#  .warning-alert .close {
#     border-color: #a97800;
#     color: #a97800;
# }
#
# li {
#   list-style: none; /* Remove default bullets */
# }
#
# ul li::before {
#   content: "•";
#   color: #B41B10;
#   font-weight: bold;
#   display: inline-block; /* Needed to add space between the bullet and the text */
#   width: 1em; /* Also needed for space (tweak if needed) */
#   margin-left: -1em; /* Also needed for space (tweak if needed) */
#   font-size:120%;
# }
#
# .number{
#     color:#B41B10;
# }
#
# mark {
#  background-color:#D59A99;
#  color:#B41B10;
#  border-radius: 6px;
#  padding: 2px 5px;
# }
#
# .btn {
#   background-color: gray;
#   border: none;
#   color: white !important;
#   padding: 5px 15px;
#   font-size: 18px;
#   cursor: pointer;
# }
#
# /* Darker background on mouse-over */
# .btn:hover {
#   background-color: Red;
# }
#
# </style>

# %% [markdown]
# <p><center style="font-family:cursive; color:#B41B10;font-size:120%;">In the name of God</center></p>
#
# # <p><center style="font-family:newtimeroman;font-size:180%;">📈 Google Stock Price Prediction (tf) 📉</center></p>
#
# <p><center style="color:#B41B10; font-family:cursive;font-size:100%;">Thanks for visiting my notebook </center></p>
#
# ***
# <br>
# <center><img src='https://i.postimg.cc/m2S3hjtP/google-stock.jpg' height=500px width=900px></center><br>
#
# <div class="alert simple-alert" style="font-family:Georgia;line-height:25px">
#     📌 Feel free to fork or edit the notebook for your own convenience. If you liked the notebook, consider upvoting. It helps other people discover the notebook as well. Your support inspires me to produce more of these kernel.😊
# </div><br><br>
#
# <p style="font-family:Georgia;line-height:25px;"><font style="font-family:Georgia; font-size:170%">🎯 Objectives of Notbook</font><br><br>
# This notebook aims to:</p>
# <ul style="font-family:Georgia;padding:0px 50px 0px 50px;line-height:30px">
#    <li>Load and normalize dataset</li>
#    <li>Visualize some image of dataset</li>
#    <li>Build, train and test LSTM model</li>
#    <li>Evaluate result of Models and find best of them</li>
#    <li>Visualize results</li>
# </ul>
#
# <center>
#     <b>📌 Like this notebook? You can support me by giving upvote</b> 😆👍🔼<br>
#     👉 <i>More about myself: <a href="https://www.kaggle.com/arezalo">www.kaggle.com/arezalo</a></i>
#     </center>
# <hr>
#
# <a id="home"></a>
#
# ### Table of contents:
#
# * [1. About Dataset](#1)
# * [2. Import Libraries & Dataset](#2)
# * [3. Overview & EDA Dataset](#3)
# * [4. Preparing Dataset](#4)
# * [5. Build, Train & Test Models](#5)
#     - [5.1. Model 1](#5_1)
#     - [5.2. Model 2](#5_2)
#     - [5.2. Model 3](#5_3)
# * [6. Select Best Model](#6)
# * [7. Evaluate Final Model & Visualize Results](#7)
# * [8. Predict Next 10 Days](#8)

# %% [markdown]
# <a id="1"></a>
# # <p style="background-image: url(https://i.postimg.cc/CLNcqSzH/finance-and-business-background-bar-chart-and-candlestick-chart-show-stock-market-trading-price-vect.jpg);font-family:newtimeroman;font-size:120%;color:white;text-align:center;border-radius:15px 50px; padding:7px">1. About Dataset</p>
#
# <a class="btn" href="#home">🏠 Tabel of Contents</a>

# %% [markdown]
# <div style="font-family:Georgia;line-height:25px">
#
# <strong>Google's Stock</strong>
#
# Google's stock, or GOOGL, is a popular choice for investors due to the company's strong financial performance and position as a leader in the technology industry. While subject to market volatility, Google's stock is considered a strong long-term investment due to the company's financials and position in the industry.
#
# The Google Stock Price dataset contains historical price information for Google's stock, covering the period from 2016-06-14 to the 2023-05-17. The dataset is made up of seven columns, each providing unique information about Google's stock performance.
#
# The following is the **structure of the data set**:
#
# </div>
#
#
# <table style="width:100%">
# <thead>
# <tr>
# <th style="text-align:center; font-weight: bold; font-size:20px">Variable Name</th>
# <th style="text-align:center; font-weight: bold; font-size:20px">Description</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><b><center>Open</center></b></td>
# <td>displays the opening price of the stock on the given date</td>
# </tr>
# <tr>
# <td><b><center>High</center></b></td>
# <td>represents the highest price at which the stock was traded during the day</td>
# </tr>
# <tr>
# <td><b><center>Low</center></b></td>
# <td>displays the lowest price at which the stock was traded during the day</td>
# </tr>
# <tr>
# <td><b><center>Close</center></b></td>
# <td>represents the closing price of the stock on the given date</td>
# </tr>
# <tr>
# <td><b><center>Volume</center></b></td>
# <td>displays the total number of shares traded on the given date</td>
# </tr>
# <tr>
# <td><b><center>Dividends</center></b></td>
# <td>Cash payments to shareholders that can reduce the stock price</td>
# </tr>
# <tr>
# <td><b><center>Stock Splits</center></b></td>
# <td>Dividing shares to increase affordability and liquidity without changing overall value</td>
# </tr>
# </tbody>
# </table>
# <br><br>
#
# <div style="font-family:Georgia;line-height:25px">
#
# The dataset provides a wealth of information for investors and analysts looking to gain insights into Google's stock performance. By analyzing the data over time, users can identify patterns and trends, evaluate the impact of external factors on stock price, and make informed investment decisions.
#
# The dataset is ideal for conducting advanced data analysis, including regression analysis, time series analysis, and predictive modeling. It can also be used to create informative visualizations, such as line graphs and candlestick charts, to better understand trends and patterns in Google's stock performance.
#
# </div>

# %% [markdown]
# <a id="2"></a>
# # <p style="background-image: url(https://i.postimg.cc/CLNcqSzH/finance-and-business-background-bar-chart-and-candlestick-chart-show-stock-market-trading-price-vect.jpg);font-family:newtimeroman;font-size:120%;color:white;text-align:center;border-radius:15px 50px; padding:7px">2. Import Libraries & Dataset</p>
#
# <a class="btn" href="#home">🏠 Tabel of Contents</a>

# %%
# import requirement libraries and tools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import tensorflow as tf
import yfinance as yf

from tensorflow import keras
from matplotlib.patches import Rectangle
from tensorflow.keras import Sequential, callbacks, regularizers 
from tensorflow.keras.layers import LSTM, Dropout, Dense, Bidirectional
from keras_tuner.tuners import RandomSearch
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
#  <div style="font-family:Georgia;line-height:25px">
# to use data from June 14, 2016, to the current date I am setting the <mark>end=None</mark> when calling the history() function. By setting <mark>end=None</mark> , the history() function will automatically retrieve the data up until the current date.

# %%
# Create a ticker object for Google (GOOGL)
ticker = yf.Ticker("GOOG")

# Define the start and end dates
start_date = "2016-06-14"

# Get historical data for the specified date range
df = ticker.history(start=start_date, end=None)
df.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2016-06-14 00:00:00-04:00  35.824001  36.123501  35.655998  35.913502
# 2016-06-15 00:00:00-04:00  35.950001  36.148998  35.865501  35.945999
# 2016-06-16 00:00:00-04:00  35.745499  35.832500  35.162998  35.518002
# 2016-06-17 00:00:00-04:00  35.432499  35.441002  34.422600  34.585999
# 2016-06-20 00:00:00-04:00  34.938499  35.124001  34.670502  34.685501
#
#                              Volume  Dividends  Stock Splits
# Date
# 2016-06-14 00:00:00-04:00  26122000        0.0           0.0
# 2016-06-15 00:00:00-04:00  24290000        0.0           0.0
# 2016-06-16 00:00:00-04:00  39650000        0.0           0.0
# 2016-06-17 00:00:00-04:00  68048000        0.0           0.0
# 2016-06-20 00:00:00-04:00  41650000        0.0           0.0

# %% [markdown]
# <div class="alert danger-alert" style="font-family:Georgia;line-height:25px">
#     ⚠ ERROR GOOG: No price data found, symbol may be delisted (1d 2016-06-14 -> 2023-05-17)<br>
#     If you encounter such an error, the problem is with your internet and you should check your internet connection and try again
# </div><br><br>

# %% [markdown]
# <a id="3"></a>
# # <p style="background-image: url(https://i.postimg.cc/CLNcqSzH/finance-and-business-background-bar-chart-and-candlestick-chart-show-stock-market-trading-price-vect.jpg);font-family:newtimeroman;font-size:120%;color:white;text-align:center;border-radius:15px 50px; padding:7px">3. Overview & EDA Dataset</p>
#
# <a class="btn" href="#home">🏠 Tabel of Contents</a>

# %%
df.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-06-26 00:00:00-04:00  121.466003  122.720001  118.989998  119.089996
# 2023-06-27 00:00:00-04:00  117.839996  119.894997  116.910004  119.010002
# 2023-06-28 00:00:00-04:00  117.959999  121.269997  117.599998  121.080002
# 2023-06-29 00:00:00-04:00  120.089996  120.910004  119.209999  120.010002
# 2023-06-30 00:00:00-04:00  121.099998  122.029999  120.879997  120.970001
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023-06-26 00:00:00-04:00  23185000        0.0           0.0
# 2023-06-27 00:00:00-04:00  27221700        0.0           0.0
# 2023-06-28 00:00:00-04:00  19753100        0.0           0.0
# 2023-06-29 00:00:00-04:00  18517500        0.0           0.0
# 2023-06-30 00:00:00-04:00  23865800        0.0           0.0

# %%
df.shape
# Out:
# (1774, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1774 entries, 2016-06-14 00:00:00-04:00 to 2023-06-30 00:00:00-04:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          1774 non-null   float64
#  1   High          1774 non-null   float64
#  2   Low           1774 non-null   float64
#  3   Close         1774 non-null   float64
#  4   Volume        1774 non-null   int64
#  5   Dividends     1774 non-null   float64
#  6   Stock Splits  1774 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 110.9 KB

# %%
df.select_dtypes(['int64','float64']).describe().T
# Out:
#                count          mean           std           min           25%  \
# Open          1774.0  7.790422e+01  3.278921e+01  3.355000e+01  5.255313e+01
# High          1774.0  7.876385e+01  3.319860e+01  3.361500e+01  5.313950e+01
# Low           1774.0  7.711512e+01  3.239624e+01  3.316420e+01  5.192263e+01
# Close         1774.0  7.795899e+01  3.279079e+01  3.341300e+01  5.255263e+01
# Volume        1774.0  3.067806e+07  1.341240e+07  6.936000e+06  2.220600e+07
# Dividends     1774.0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Stock Splits  1774.0  1.127396e-02  4.748464e-01  0.000000e+00  0.000000e+00
#
#                        50%           75%           max
# Open          6.381700e+01  1.041486e+02  1.518635e+02
# High          6.467600e+01  1.058854e+02  1.521000e+02
# Low           6.329913e+01  1.032925e+02  1.498875e+02
# Close         6.409100e+01  1.047664e+02  1.507090e+02
# Volume        2.712100e+07  3.452150e+07  1.241400e+08
# Dividends     0.000000e+00  0.000000e+00  0.000000e+00
# Stock Splits  0.000000e+00  0.000000e+00  2.000000e+01

# %%
df.isna().sum().to_frame(name='num_of_NaN')
# Out:
#               num_of_NaN
# Open                   0
# High                   0
# Low                    0
# Close                  0
# Volume                 0
# Dividends              0
# Stock Splits           0

# %% [markdown]
# <div style="font-family:Georgia;line-height:25px">Thank God 🤲, the data does not have any missing value</div>

# %%
df.plot(subplots=True, figsize=(15, 15))
plt.suptitle('Google stock attributes from 2016 to 2023', y=0.91)
plt.show()

# %%
df.asfreq('M').ffill().plot(subplots=True, figsize=(15,15), style='-')
plt.suptitle('Google Stock attributes over time(Monthly frequency)', y=0.91)
plt.show()

# %%
df[['Close']]
# Out:
#                                 Close
# Date
# 2016-06-14 00:00:00-04:00   35.913502
# 2016-06-15 00:00:00-04:00   35.945999
# 2016-06-16 00:00:00-04:00   35.518002
# 2016-06-17 00:00:00-04:00   34.585999
# 2016-06-20 00:00:00-04:00   34.685501
# ...                               ...
# 2023-06-26 00:00:00-04:00  119.089996
# 2023-06-27 00:00:00-04:00  119.010002
# 2023-06-28 00:00:00-04:00  121.080002
# 2023-06-29 00:00:00-04:00  120.010002
# 2023-06-30 00:00:00-04:00  120.970001
#
# [1774 rows x 1 columns]

# %%
# computing moving average(ma)
ma_day = [10, 20, 50]

for ma in ma_day:
    col_name = f'MA for {ma} days'
    df[col_name] = df['Close'].rolling(ma).mean()

df[['Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(figsize=(15,5))
plt.title('Comparision some MA and Close of Google stock')
plt.show()

# %% [markdown]
# <div style="font-family:Georgia;line-height:25px">
# We see in the graph that the best values to measure the moving average are <mark>10 and 20 days</mark> because we still capture trends in the data without noise.</div>

# %%
# use pct_change to find the percent change for each day
df['Daily_Return'] = df['Close'].pct_change()
# plot the daily return percentage
df.Daily_Return.plot(legend=True, figsize=(15,5))
plt.title('Daily return percentage of Google stock')
plt.show()

# %%
# Create a trace for the candlestick chart
candlestick_trace = go.Candlestick(
    x=df.index,
    open=df['Open'],
    high=df['High'],
    low=df['Low'],
    close=df['Close'],
    name='Candlestick'
)

# Create the layout
layout = go.Layout(
    title='GOOG Candlestick Chart',
    xaxis=dict(title='Date'),
    yaxis=dict(title='Price', rangemode='normal')
)

# Create the figure and add the candlestick trace and layout
fig = go.Figure(data=[candlestick_trace], layout=layout)

# Update the layout of the figure
fig.update_layout(xaxis_rangeslider_visible=False)

# Show the figure
fig.show()

# %% [markdown]
# <a id="4"></a>
# # <p style="background-image: url(https://i.postimg.cc/CLNcqSzH/finance-and-business-background-bar-chart-and-candlestick-chart-show-stock-market-trading-price-vect.jpg);font-family:newtimeroman;font-size:120%;color:white;text-align:center;border-radius:15px 50px; padding:7px">4. Preparing Dataset</p>
#
# <a class="btn" href="#home">🏠 Tabel of Contents</a>

# %% [markdown]
# <div style="font-family:Georgia;line-height:25px">
# <strong>Data Normalization</strong>
#
# This is an important pre-processing step for neural networks:
# </div>

# %%
# normalize data
df2 = df.copy(deep=True)
scaler = MinMaxScaler(feature_range=(0,15)).fit(df2.Low.values.reshape(-1,1))
df2['Open'] = scaler.transform(df2.Open.values.reshape(-1,1))
df2['High'] = scaler.transform(df2.High.values.reshape(-1,1))
df2['Low'] = scaler.transform(df2.Low.values.reshape(-1,1))
df2['Close'] = scaler.transform(df2.Close.values.reshape(-1,1))
data = df2[['Open','High','Low', 'Close']].values
data.shape
# Out:
# (1774, 4)

# %%
data
# Out:
# array([[ 0.34180856,  0.38029696,  0.32021864,  0.35331018],
#        [ 0.35800063,  0.38357361,  0.3471417 ,  0.35748639],
#        [ 0.33172026,  0.34290078,  0.25686368,  0.30248482],
#        ...,
#        [10.89702759, 11.32239223, 10.85076425, 11.29797618],
#        [11.17075151, 11.27612987, 11.0576639 , 11.16047153],
#        [11.30054593, 11.42005938, 11.27227378, 11.2838401 ]])

# %% [markdown]
# <div style="font-family:Georgia;line-height:25px">
# <strong>Preparing Data for Time Series</strong>
#
# In order to prepare the dataset for stock price prediction, we need to frame it as a time series problem. We will use the price from the previous 10 days to predict the price on the next day. Let’s
# create the sequences accordingly:
# </div>

# %%
seq_len=11
sequences=[]
for index in range(len(data) - seq_len + 1): 
    sequences.append(data[index: index + seq_len])
sequences= np.array(sequences)

# %% [markdown]
# <div style="font-family:Georgia;line-height:25px">
# <strong>Splitting the Data</strong>
#
# We divide the entire dataset into three parts. 80% for the training set, 10% for the validation set and the remaining 10% for the test set:
# </div>

# %%
valid_set_size_percentage = 10 
test_set_size_percentage = 10 

valid_set_size = int(np.round(valid_set_size_percentage/100*sequences.shape[0]))  
test_set_size  = int(np.round(test_set_size_percentage/100*sequences.shape[0]))
train_set_size = sequences.shape[0] - (valid_set_size + test_set_size)

x_train = sequences[:train_set_size,:-1,:]
y_train = sequences[:train_set_size,-1,:]
    
x_valid = sequences[train_set_size:train_set_size+valid_set_size,:-1,:]
y_valid = sequences[train_set_size:train_set_size+valid_set_size,-1,:]
    
x_test = sequences[train_set_size+valid_set_size:,:-1,:]
y_test = sequences[train_set_size+valid_set_size:,-1,:]

# %% [markdown]
# <a id="5"></a>
# # <p style="background-image: url(https://i.postimg.cc/CLNcqSzH/finance-and-business-background-bar-chart-and-candlestick-chart-show-stock-market-trading-price-vect.jpg);font-family:newtimeroman;font-size:120%;color:white;text-align:center;border-radius:15px 50px; padding:7px">5. Build, Train & Test Models</p>
#
# <a class="btn" href="#home">🏠 Tabel of Contents</a>

# %% [markdown]
# <a id="5_1"></a>
# # <p style="background-image: url(https://i.postimg.cc/CLNcqSzH/finance-and-business-background-bar-chart-and-candlestick-chart-show-stock-market-trading-price-vect.jpg);font-family:newtimeroman;font-size:100%;color:white;text-align:center;border-radius:15px 50px; padding:7px">5.1. Model 1 (Vanilla LSTM)</p>
#
# <a class="btn" href="#home">🏠 Tabel of Contents</a>

# %% [markdown]
# <div style="font-family:Georgia;line-height:25px">
# A Vanilla LSTM is an LSTM model that has a single hidden layer of LSTM units, and an output layer used to make a prediction</div>

# %%
# build model 1 (Vanilla LSTM)
model1 = Sequential()
model1.add(LSTM(units=50, input_shape=(seq_len-1,4), kernel_regularizer=regularizers.l2(0.001)))
model1.add(Dense(units=4))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                11000
#
#  dense (Dense)               (None, 4)                 204
#
# =================================================================
# Total params: 11,204
# Trainable params: 11,204
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model 1
model1.compile(optimizer='adam', loss='mean_squared_error', metrics=['msle'])

# %%
model1_hist  = model1.fit(
    x_train,
    y_train,
    epochs=50,
    batch_size=64,
    validation_data=(x_valid, y_valid),
)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 7s 61ms/step - loss: 36.3014 - msle: 1.9704 - val_loss: 99.5521 - val_msle: 3.0683
# Epoch 2/50
# 23/23 [==============================] - 0s 20ms/step - loss: 23.6793 - msle: 0.6416 - val_loss: 66.8808 - val_msle: 1.2644
# Epoch 3/50
# 23/23 [==============================] - 0s 15ms/step - loss: 15.6277 - msle: 0.2651 - val_loss: 45.9027 - val_msle: 0.6698
# Epoch 4/50
# 23/23 [==============================] - 0s 18ms/step - loss: 11.2419 - msle: 0.1401 - val_loss: 33.3559 - val_msle: 0.4090
# Epoch 5/50
# 23/23 [==============================] - 0s 18ms/step - loss: 8.4574 - msle: 0.0879 - val_loss: 23.3058 - val_msle: 0.2439
# Epoch 6/50
# 23/23 [==============================] - 1s 24ms/step - loss: 6.3647 - msle: 0.0578 - val_loss: 16.3849 - val_msle: 0.1526
# Epoch 7/50
# 23/23 [==============================] - 1s 23ms/step - loss: 4.7339 - msle: 0.0388 - val_loss: 11.0588 - val_msle: 0.0929
# Epoch 8/50
# 23/23 [==============================] - 0s 21ms/step - loss: 3.4634 - msle: 0.0264 - val_loss: 6.6648 - val_msle: 0.0502
# Epoch 9/50
# 23/23 [==============================] - 1s 23ms/step - loss: 2.3804 - msle: 0.0169 - val_loss: 4.2312 - val_msle: 0.0293
# Epoch 10/50
# 23/23 [==============================] - 0s 17ms/step - loss: 1.7267 - msle: 0.0119 - val_loss: 2.7664 - val_msle: 0.0179
# Epoch 11/50
# 23/23 [==============================] - 0s 21ms/step - loss: 1.2825 - msle: 0.0087 - val_loss: 1.9662 - val_msle: 0.0123
# Epoch 12/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.9380 - msle: 0.0064 - val_loss: 1.3323 - val_msle: 0.0080
# Epoch 13/50
# 23/23 [==============================] - 0s 19ms/step - loss: 0.7005 - msle: 0.0048 - val_loss: 0.9980 - val_msle: 0.0060
# Epoch 14/50
# 23/23 [==============================] - 0s 19ms/step - loss: 0.5402 - msle: 0.0038 - val_loss: 0.7087 - val_msle: 0.0042
# Epoch 15/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4222 - msle: 0.0032 - val_loss: 0.7327 - val_msle: 0.0047
# Epoch 16/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3344 - msle: 0.0027 - val_loss: 0.4142 - val_msle: 0.0025
# Epoch 17/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.2574 - msle: 0.0022 - val_loss: 0.3466 - val_msle: 0.0022
# Epoch 18/50
# 23/23 [==============================] - 0s 14ms/step - loss: 0.1951 - msle: 0.0019 - val_loss: 0.2854 - val_msle: 0.0018
# Epoch 19/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1615 - msle: 0.0017 - val_loss: 0.2934 - val_msle: 0.0019
# Epoch 20/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1324 - msle: 0.0015 - val_loss: 0.2606 - val_msle: 0.0017
# Epoch 21/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1160 - msle: 0.0015 - val_loss: 0.2936 - val_msle: 0.0019
# Epoch 22/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.1060 - msle: 0.0015 - val_loss: 0.4028 - val_msle: 0.0027
# Epoch 23/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0916 - msle: 0.0013 - val_loss: 0.2187 - val_msle: 0.0014
# Epoch 24/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0834 - msle: 0.0014 - val_loss: 0.2373 - val_msle: 0.0016
# Epoch 25/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0743 - msle: 0.0012 - val_loss: 0.2033 - val_msle: 0.0013
# Epoch 26/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0706 - msle: 0.0013 - val_loss: 0.3122 - val_msle: 0.0021
# Epoch 27/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0701 - msle: 0.0012 - val_loss: 0.1995 - val_msle: 0.0013
# Epoch 28/50
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0636 - msle: 0.0011 - val_loss: 0.2003 - val_msle: 0.0013
# Epoch 29/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0592 - msle: 0.0011 - val_loss: 0.1851 - val_msle: 0.0012
# Epoch 30/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0592 - msle: 0.0012 - val_loss: 0.2038 - val_msle: 0.0013
# Epoch 31/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0554 - msle: 0.0011 - val_loss: 0.1981 - val_msle: 0.0013
# Epoch 32/50
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0533 - msle: 0.0010 - val_loss: 0.1777 - val_msle: 0.0012
# Epoch 33/50
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0516 - msle: 0.0011 - val_loss: 0.2543 - val_msle: 0.0016
# Epoch 34/50
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0534 - msle: 0.0011 - val_loss: 0.1561 - val_msle: 0.0010
# Epoch 35/50
# 23/23 [==============================] - 0s 15ms/step - loss: 0.0485 - msle: 9.8894e-04 - val_loss: 0.1696 - val_msle: 0.0011
# Epoch 36/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0497 - msle: 0.0011 - val_loss: 0.1529 - val_msle: 0.0010
# Epoch 37/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0472 - msle: 0.0011 - val_loss: 0.1564 - val_msle: 0.0010
# Epoch 38/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0448 - msle: 9.6215e-04 - val_loss: 0.2119 - val_msle: 0.0014
# Epoch 39/50
# 23/23 [==============================] - 1s 22ms/step - loss: 0.0478 - msle: 0.0011 - val_loss: 0.1552 - val_msle: 0.0010
# Epoch 40/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0437 - msle: 9.5689e-04 - val_loss: 0.1769 - val_msle: 0.0011
# Epoch 41/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0412 - msle: 8.9028e-04 - val_loss: 0.3047 - val_msle: 0.0019
# Epoch 42/50
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0481 - msle: 0.0011 - val_loss: 0.1509 - val_msle: 9.7464e-04
# Epoch 43/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0424 - msle: 9.3797e-04 - val_loss: 0.1370 - val_msle: 8.8131e-04
# Epoch 44/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0406 - msle: 8.8525e-04 - val_loss: 0.1275 - val_msle: 8.4108e-04
# Epoch 45/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0534 - msle: 0.0012 - val_loss: 0.1539 - val_msle: 9.6630e-04
# Epoch 46/50
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0456 - msle: 9.9691e-04 - val_loss: 0.1272 - val_msle: 8.3281e-04
# Epoch 47/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0452 - msle: 0.0010 - val_loss: 0.2040 - val_msle: 0.0013
# Epoch 48/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0403 - msle: 8.8092e-04 - val_loss: 0.1355 - val_msle: 8.8000e-04
# Epoch 49/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0387 - msle: 8.5407e-04 - val_loss: 0.1525 - val_msle: 9.5471e-04
# Epoch 50/50
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0393 - msle: 9.3220e-04 - val_loss: 0.1216 - val_msle: 8.0758e-04

# %%
def plot_model_history(model_hist):
    """
    Plot diagram of accuracy and loss for train and validation set
        model_hist: results of model
    """
    
    fig, axs = plt.subplots(2, 1, figsize=(10, 12))
    
    # Plot train and validation accuracy
    axs[0].plot(model_hist.history['msle'], color="red", marker="o")
    axs[0].plot(model_hist.history['val_msle'], color="blue", marker="h")
    axs[0].set_title('MSLE Comparison between Train & Validation Set')
    axs[0].set_ylabel('msle')
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['Train', 'Validation'], loc="lower right")
    
    # Plot train and validation loss
    axs[1].plot(model_hist.history['loss'], color="red", marker="o")
    axs[1].plot(model_hist.history['val_loss'], color="blue", marker="h")
    axs[1].set_title('Loss Comparison between Train & Validation Set')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].legend(['Train', 'Validation'], loc="upper right")

    plt.tight_layout()
    plt.show()

# %%
plot_model_history(model1_hist)

# %%
predictions1 = model1.predict(x_test)
# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, predictions1))
print(f'RMSE of Model 1: {rmse:0.3}')

predictions1 = scaler.inverse_transform(predictions1)
# Out:
# 6/6 [==============================] - 1s 4ms/step
# RMSE of Model 1: 0.283

# %%
model1.evaluate(x_test, y_test)
# Out:
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0870 - msle: 8.7252e-04
# [0.0870387926697731, 0.0008725151419639587]

# %%
# Plotting the data
def plot_predictions(predictions, idx, data_source=df, test_range=len(df) - len(y_test)):

    plt.figure(figsize=(15, 8))
    plt.subplot(2, 1, 1,)    
    plt.title('Model', fontsize = 18)
    plt.xlabel('Date', fontsize = 14)
    plt.ylabel('Closing Price', fontsize = 14)
    plt.plot(df.iloc[:test_range, idx])
    plt.plot(df.iloc[test_range:, idx])
    plt.plot(df[test_range:].index, predictions[:, idx])

    # dates = pd.date_range('2023-01-04', periods=133, freq='D')

    # Define the window start and end dates
    window_start = df[test_range:].index[0]
    window_end = df[test_range:].index[-1]

    # Define width and height
    width = window_end - window_start
    height = max(predictions[:, idx]) - min(predictions[:, idx]) + 30

    # Create a Rectangle object
    rectangle = Rectangle((window_start, min(predictions[:, idx])-10), width, height, fill=False, edgecolor='red', linestyle='dashed')

    # Add the Rectangle to the plot
    plt.gca().add_patch(rectangle)
    
    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 2)
    plt.title('Model', fontsize = 14)
    plt.xlabel('Date', fontsize = 12)
    plt.ylabel('Closing Price', fontsize = 12)
    plt.xticks(rotation=45)
    plt.plot(df.iloc[test_range:, idx], color='orange', label='Close')
    plt.plot(df.iloc[test_range:].index, predictions[:, idx], color='green', label='Pred')
    plt.legend(['test', 'Prediction'], loc = 'lower right')

    plt.tight_layout()
    plt.show()

# %%
plot_predictions(predictions1, 2, data_source=df)

# %% [markdown]
# <a id="5_2"></a>
# # <p style="background-image: url(https://i.postimg.cc/CLNcqSzH/finance-and-business-background-bar-chart-and-candlestick-chart-show-stock-market-trading-price-vect.jpg);font-family:newtimeroman;font-size:100%;color:white;text-align:center;border-radius:15px 50px; padding:7px">5.2. Model 2 (Stacked LSTM)</p>
#
# <a class="btn" href="#home">🏠 Tabel of Contents</a>

# %% [markdown]
# <div style="font-family:Georgia;line-height:25px">
# Multiple hidden LSTM layers can be stacked one on top of another in what is referred to as a Stacked LSTM model.</div>

# %%
# build model2
model2 = Sequential()
model2.add(LSTM(units=50, return_sequences=True, input_shape=(seq_len-1, 4)))
model2.add(LSTM(units=50))
model2.add(Dropout(0.2))
model2.add(Dense(units=4))

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 10, 50)            11000
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense_1 (Dense)             (None, 4)                 204
#
# =================================================================
# Total params: 31,404
# Trainable params: 31,404
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile model2
model2.compile(optimizer='adam', loss='mse', metrics=['msle'])

# %%
# fit model2
model2_hist  = model2.fit(
    x_train,
    y_train,
    epochs=50,
    batch_size=64,
    validation_data=(x_valid, y_valid),
)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 9s 98ms/step - loss: 30.9917 - msle: 1.5015 - val_loss: 71.6365 - val_msle: 1.4599
# Epoch 2/50
# 23/23 [==============================] - 1s 29ms/step - loss: 16.0160 - msle: 0.3354 - val_loss: 39.6928 - val_msle: 0.5222
# Epoch 3/50
# 23/23 [==============================] - 1s 32ms/step - loss: 9.4920 - msle: 0.1303 - val_loss: 22.8000 - val_msle: 0.2444
# Epoch 4/50
# 23/23 [==============================] - 1s 26ms/step - loss: 6.0887 - msle: 0.0695 - val_loss: 13.5525 - val_msle: 0.1241
# Epoch 5/50
# 23/23 [==============================] - 1s 23ms/step - loss: 4.1890 - msle: 0.0436 - val_loss: 8.4416 - val_msle: 0.0687
# Epoch 6/50
# 23/23 [==============================] - 1s 23ms/step - loss: 3.0722 - msle: 0.0317 - val_loss: 5.4525 - val_msle: 0.0405
# Epoch 7/50
# 23/23 [==============================] - 1s 23ms/step - loss: 2.4454 - msle: 0.0258 - val_loss: 3.6830 - val_msle: 0.0257
# Epoch 8/50
# 23/23 [==============================] - 1s 23ms/step - loss: 1.7685 - msle: 0.0187 - val_loss: 2.3625 - val_msle: 0.0155
# Epoch 9/50
# 23/23 [==============================] - 1s 24ms/step - loss: 1.3691 - msle: 0.0152 - val_loss: 2.0192 - val_msle: 0.0135
# Epoch 10/50
# 23/23 [==============================] - 1s 23ms/step - loss: 1.1892 - msle: 0.0147 - val_loss: 1.0956 - val_msle: 0.0068
# Epoch 11/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.9131 - msle: 0.0115 - val_loss: 1.1571 - val_msle: 0.0078
# Epoch 12/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.8168 - msle: 0.0100 - val_loss: 0.8429 - val_msle: 0.0057
# Epoch 13/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.6776 - msle: 0.0103 - val_loss: 0.5079 - val_msle: 0.0032
# Epoch 14/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.5145 - msle: 0.0084 - val_loss: 0.5524 - val_msle: 0.0038
# Epoch 15/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.4777 - msle: 0.0072 - val_loss: 0.3855 - val_msle: 0.0026
# Epoch 16/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.4076 - msle: 0.0067 - val_loss: 0.3757 - val_msle: 0.0025
# Epoch 17/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.4489 - msle: 0.0078 - val_loss: 0.6906 - val_msle: 0.0047
# Epoch 18/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.5166 - msle: 0.0111 - val_loss: 0.3985 - val_msle: 0.0027
# Epoch 19/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.4384 - msle: 0.0074 - val_loss: 0.3588 - val_msle: 0.0025
# Epoch 20/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3744 - msle: 0.0067 - val_loss: 0.2972 - val_msle: 0.0020
# Epoch 21/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3655 - msle: 0.0063 - val_loss: 0.5109 - val_msle: 0.0035
# Epoch 22/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3560 - msle: 0.0061 - val_loss: 0.4393 - val_msle: 0.0030
# Epoch 23/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3846 - msle: 0.0060 - val_loss: 1.2689 - val_msle: 0.0090
# Epoch 24/50
# 23/23 [==============================] - 1s 25ms/step - loss: 0.3939 - msle: 0.0072 - val_loss: 0.4761 - val_msle: 0.0033
# Epoch 25/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3453 - msle: 0.0062 - val_loss: 0.3744 - val_msle: 0.0024
# Epoch 26/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3366 - msle: 0.0055 - val_loss: 0.5217 - val_msle: 0.0033
# Epoch 27/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3196 - msle: 0.0057 - val_loss: 0.2768 - val_msle: 0.0019
# Epoch 28/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3244 - msle: 0.0053 - val_loss: 0.6424 - val_msle: 0.0048
# Epoch 29/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.4198 - msle: 0.0087 - val_loss: 0.3563 - val_msle: 0.0026
# Epoch 30/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3773 - msle: 0.0073 - val_loss: 0.2969 - val_msle: 0.0021
# Epoch 31/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3529 - msle: 0.0057 - val_loss: 0.2960 - val_msle: 0.0021
# Epoch 32/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3126 - msle: 0.0053 - val_loss: 0.2763 - val_msle: 0.0019
# Epoch 33/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.2844 - msle: 0.0049 - val_loss: 0.2982 - val_msle: 0.0020
# Epoch 34/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3284 - msle: 0.0057 - val_loss: 0.2278 - val_msle: 0.0016
# Epoch 35/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3101 - msle: 0.0051 - val_loss: 0.3096 - val_msle: 0.0021
# Epoch 36/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3412 - msle: 0.0056 - val_loss: 0.4141 - val_msle: 0.0025
# Epoch 37/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.2894 - msle: 0.0051 - val_loss: 0.8833 - val_msle: 0.0064
# Epoch 38/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.4133 - msle: 0.0069 - val_loss: 0.2831 - val_msle: 0.0020
# Epoch 39/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3091 - msle: 0.0053 - val_loss: 0.2073 - val_msle: 0.0014
# Epoch 40/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3089 - msle: 0.0050 - val_loss: 0.3195 - val_msle: 0.0023
# Epoch 41/50
# 23/23 [==============================] - 1s 24ms/step - loss: 0.3869 - msle: 0.0070 - val_loss: 0.2355 - val_msle: 0.0016
# Epoch 42/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3062 - msle: 0.0049 - val_loss: 0.2320 - val_msle: 0.0016
# Epoch 43/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.2996 - msle: 0.0051 - val_loss: 0.2153 - val_msle: 0.0014
# Epoch 44/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3328 - msle: 0.0052 - val_loss: 0.2769 - val_msle: 0.0018
# Epoch 45/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3149 - msle: 0.0054 - val_loss: 0.2495 - val_msle: 0.0017
# Epoch 46/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.2787 - msle: 0.0050 - val_loss: 0.2770 - val_msle: 0.0019
# Epoch 47/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.2956 - msle: 0.0054 - val_loss: 0.1844 - val_msle: 0.0012
# Epoch 48/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.2719 - msle: 0.0050 - val_loss: 0.1657 - val_msle: 0.0011
# Epoch 49/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.3444 - msle: 0.0055 - val_loss: 0.2115 - val_msle: 0.0015
# Epoch 50/50
# 23/23 [==============================] - 1s 23ms/step - loss: 0.2863 - msle: 0.0050 - val_loss: 0.2144 - val_msle: 0.0014

# %%
plot_model_history(model2_hist)

# %%
predictions2 = model2.predict(x_test)
# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, predictions2))
print(f'RMSE of Model 2: {rmse:0.3}')

predictions2 = scaler.inverse_transform(predictions2)
# Out:
# 6/6 [==============================] - 2s 7ms/step
# RMSE of Model 2: 0.319

# %%
model2.evaluate(x_test, y_test)
# Out:
# 6/6 [==============================] - 0s 8ms/step - loss: 0.1016 - msle: 0.0011
# [0.10159765928983688, 0.0010915753664448857]

# %%
plot_predictions(predictions2, 3, data_source=df)

# %% [markdown]
# <a id="5_3"></a>
# # <p style="background-image: url(https://i.postimg.cc/CLNcqSzH/finance-and-business-background-bar-chart-and-candlestick-chart-show-stock-market-trading-price-vect.jpg);font-family:newtimeroman;font-size:100%;color:white;text-align:center;border-radius:15px 50px; padding:7px">5.3. Model 3 (Bidirectional LSTM)</p>
#
# <a class="btn" href="#home">🏠 Tabel of Contents</a>

# %% [markdown]
# <div style="font-family:Georgia;line-height:25px">
#
# On some sequence prediction problems, it can be beneficial to allow the LSTM model to learn the input sequence both forward and backwards and concatenate both interpretations.
#
# This is called a Bidirectional LSTM.
#
# We can implement a Bidirectional LSTM for univariate time series forecasting by wrapping the first hidden layer in a wrapper layer called Bidirectional.
# </div>

# %%
# build model3
model3 = Sequential()
model3.add(Bidirectional(LSTM(units=50, input_shape=(seq_len-1, 4), kernel_regularizer=regularizers.l2(0.001))))
model3.add(Dense(units=4))

# %%
# compile model3
model3.compile(optimizer='adam', loss='mse', metrics=['msle'])

# %%
model3_hist  = model3.fit(
    x_train,
    y_train,
    epochs=50,
    batch_size=64,
    validation_data=(x_valid, y_valid),
)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 11s 94ms/step - loss: 27.2606 - msle: 1.0066 - val_loss: 67.1645 - val_msle: 1.2874
# Epoch 2/50
# 23/23 [==============================] - 0s 18ms/step - loss: 13.6879 - msle: 0.2269 - val_loss: 30.4766 - val_msle: 0.3512
# Epoch 3/50
# 23/23 [==============================] - 0s 21ms/step - loss: 6.6204 - msle: 0.0659 - val_loss: 11.8700 - val_msle: 0.1003
# Epoch 4/50
# 23/23 [==============================] - 0s 21ms/step - loss: 3.0588 - msle: 0.0238 - val_loss: 4.0495 - val_msle: 0.0272
# Epoch 5/50
# 23/23 [==============================] - 1s 22ms/step - loss: 1.4525 - msle: 0.0109 - val_loss: 1.8790 - val_msle: 0.0119
# Epoch 6/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.7400 - msle: 0.0060 - val_loss: 0.8629 - val_msle: 0.0053
# Epoch 7/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.4040 - msle: 0.0042 - val_loss: 0.4575 - val_msle: 0.0028
# Epoch 8/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.2446 - msle: 0.0031 - val_loss: 1.0137 - val_msle: 0.0070
# Epoch 9/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.1664 - msle: 0.0024 - val_loss: 0.3916 - val_msle: 0.0026
# Epoch 10/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.1191 - msle: 0.0020 - val_loss: 0.3948 - val_msle: 0.0027
# Epoch 11/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.1025 - msle: 0.0019 - val_loss: 0.3501 - val_msle: 0.0022
# Epoch 12/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0901 - msle: 0.0018 - val_loss: 0.3869 - val_msle: 0.0025
# Epoch 13/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0822 - msle: 0.0017 - val_loss: 0.3690 - val_msle: 0.0023
# Epoch 14/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0817 - msle: 0.0018 - val_loss: 0.2899 - val_msle: 0.0018
# Epoch 15/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0760 - msle: 0.0017 - val_loss: 0.3721 - val_msle: 0.0024
# Epoch 16/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0717 - msle: 0.0015 - val_loss: 0.3509 - val_msle: 0.0022
# Epoch 17/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0707 - msle: 0.0015 - val_loss: 0.3624 - val_msle: 0.0022
# Epoch 18/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0694 - msle: 0.0014 - val_loss: 0.2586 - val_msle: 0.0017
# Epoch 19/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0664 - msle: 0.0015 - val_loss: 0.4709 - val_msle: 0.0031
# Epoch 20/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0699 - msle: 0.0015 - val_loss: 0.4289 - val_msle: 0.0028
# Epoch 21/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0715 - msle: 0.0015 - val_loss: 0.2309 - val_msle: 0.0015
# Epoch 22/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0612 - msle: 0.0014 - val_loss: 0.5327 - val_msle: 0.0035
# Epoch 23/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0652 - msle: 0.0014 - val_loss: 0.2355 - val_msle: 0.0015
# Epoch 24/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0591 - msle: 0.0014 - val_loss: 0.2853 - val_msle: 0.0018
# Epoch 25/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0585 - msle: 0.0013 - val_loss: 0.2239 - val_msle: 0.0014
# Epoch 26/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0579 - msle: 0.0013 - val_loss: 0.3905 - val_msle: 0.0027
# Epoch 27/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0595 - msle: 0.0014 - val_loss: 0.3404 - val_msle: 0.0024
# Epoch 28/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0575 - msle: 0.0013 - val_loss: 0.2891 - val_msle: 0.0020
# Epoch 29/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0569 - msle: 0.0013 - val_loss: 0.1962 - val_msle: 0.0013
# Epoch 30/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0621 - msle: 0.0014 - val_loss: 0.2411 - val_msle: 0.0015
# Epoch 31/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0749 - msle: 0.0016 - val_loss: 0.3175 - val_msle: 0.0022
# Epoch 32/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0577 - msle: 0.0013 - val_loss: 0.1698 - val_msle: 0.0011
# Epoch 33/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0539 - msle: 0.0012 - val_loss: 0.2831 - val_msle: 0.0017
# Epoch 34/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0575 - msle: 0.0014 - val_loss: 0.2602 - val_msle: 0.0016
# Epoch 35/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0546 - msle: 0.0013 - val_loss: 0.2012 - val_msle: 0.0013
# Epoch 36/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0523 - msle: 0.0012 - val_loss: 0.2022 - val_msle: 0.0013
# Epoch 37/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0576 - msle: 0.0014 - val_loss: 0.1835 - val_msle: 0.0012
# Epoch 38/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0542 - msle: 0.0012 - val_loss: 0.2541 - val_msle: 0.0016
# Epoch 39/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0516 - msle: 0.0012 - val_loss: 0.2190 - val_msle: 0.0015
# Epoch 40/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0487 - msle: 0.0011 - val_loss: 0.1632 - val_msle: 0.0011
# Epoch 41/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0517 - msle: 0.0012 - val_loss: 0.1941 - val_msle: 0.0013
# Epoch 42/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0476 - msle: 0.0011 - val_loss: 0.1459 - val_msle: 9.1879e-04
# Epoch 43/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0485 - msle: 0.0010 - val_loss: 0.1833 - val_msle: 0.0012
# Epoch 44/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0461 - msle: 0.0011 - val_loss: 0.2390 - val_msle: 0.0015
# Epoch 45/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0484 - msle: 0.0011 - val_loss: 0.1868 - val_msle: 0.0012
# Epoch 46/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0481 - msle: 0.0011 - val_loss: 0.1811 - val_msle: 0.0012
# Epoch 47/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0468 - msle: 0.0010 - val_loss: 0.2535 - val_msle: 0.0017
# Epoch 48/50
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0460 - msle: 9.7662e-04 - val_loss: 0.2129 - val_msle: 0.0014
# Epoch 49/50
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0474 - msle: 0.0011 - val_loss: 0.1843 - val_msle: 0.0012
# Epoch 50/50
# 23/23 [==============================] - 0s 17ms/step - loss: 0.0462 - msle: 9.9445e-04 - val_loss: 0.1346 - val_msle: 8.4467e-04

# %%
plot_model_history(model3_hist)

# %%
predictions3= model3.predict(x_test)
# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, predictions3))
print(f'RMSE of Model 3: {rmse:0.3}')

predictions3 = scaler.inverse_transform(predictions3)
# Out:
# 6/6 [==============================] - 2s 5ms/step
# RMSE of Model 3: 0.314

# %%
model3.evaluate(x_test, y_test)
# Out:
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1109 - msle: 0.0010
# [0.11086085438728333, 0.0010267358738929033]

# %%
plot_predictions(predictions3, 3, df)

# %% [markdown]
# <a id="6"></a>
# # <p style="background-image: url(https://i.postimg.cc/CLNcqSzH/finance-and-business-background-bar-chart-and-candlestick-chart-show-stock-market-trading-price-vect.jpg);font-family:newtimeroman;font-size:120%;color:white;text-align:center;border-radius:15px 50px; padding:7px">6. Select Best Model</p>
#
# <a class="btn" href="#home">🏠 Tabel of Contents</a>

# %% [markdown]
# <div style="font-family:Georgia;line-height:25px">
# Almost all the models show a good performance, but it seems that the second model has the best performance, so we save this model as the final model and we can use it to predict the future days.
# </div>

# %%
# Save the entire model to a HDF5 file.
model1.save('best_model.h5')

# %%
# select best model
# Recreate the exact same model, including its weights and the optimizer
final_model = tf.keras.models.load_model('best_model.h5')

# Show the model architecture
final_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                11000
#
#  dense (Dense)               (None, 4)                 204
#
# =================================================================
# Total params: 11,204
# Trainable params: 11,204
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <a id="7"></a>
# # <p style="background-image: url(https://i.postimg.cc/CLNcqSzH/finance-and-business-background-bar-chart-and-candlestick-chart-show-stock-market-trading-price-vect.jpg);font-family:newtimeroman;font-size:120%;color:white;text-align:center;border-radius:15px 50px; padding:7px">7. Evaluate Final Model & Visualize Results</p>
#
# <a class="btn" href="#home">🏠 Tabel of Contents</a>

# %%
# Evaluate Finanl model and check it
test_loss, test_msle = final_model.evaluate(x_test, y_test, verbose=2)
print(f'\nTest loss:{test_loss:0.3} (Test msle: {test_msle:0.3})')
# Out:
# 6/6 - 1s - loss: 0.0870 - msle: 8.7252e-04 - 848ms/epoch - 141ms/step
#
# Test loss:0.087 (Test msle: 0.000873)

# %%
predictions = final_model.predict(x_test)
# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f'RMSE of Final Model: {rmse:0.3}')

predictions = scaler.inverse_transform(predictions)
# Out:
# 6/6 [==============================] - 1s 4ms/step
# RMSE of Final Model: 0.283

# %%
plot_predictions(predictions, 3, df)

# %%
index_values = df[len(df) - len(y_test):].index
col_values = ['Open', 'Low', 'High', 'Close']
df_results = pd.DataFrame(data=predictions, index=index_values, columns=col_values)

# %%
# Create a trace for the candlestick chart
candlestick_trace = go.Candlestick(
    x=df_results.index,
    open=df_results['Open'],
    high=df_results['High'],
    low=df_results['Low'],
    close=df_results['Close'],
    name='Candlestick'
)

# Create the layout
layout = go.Layout(
    title='GOOG Candlestick Chart',
    xaxis=dict(title='Date'),
    yaxis=dict(title='Price', rangemode='normal')
)

# Create the figure and add the candlestick trace and layout
fig = go.Figure(data=[candlestick_trace], layout=layout)

# Update the layout of the figure
fig.update_layout(xaxis_rangeslider_visible=False)

# Show the figure
fig.show()

# %% [markdown]
# <a id="8"></a>
# # <p style="background-image: url(https://i.postimg.cc/CLNcqSzH/finance-and-business-background-bar-chart-and-candlestick-chart-show-stock-market-trading-price-vect.jpg);font-family:newtimeroman;font-size:120%;color:white;text-align:center;border-radius:15px 50px; padding:7px">8. Predict Next 10 Days</p>
#
# <a class="btn" href="#home">🏠 Tabel of Contents</a>

# %%
# predict next 10 days of stock price

# Get the last sequence of historical as features for preidict next 10 days
last_sequence = sequences[-1:, 1:, :]

# Generate predictions for the next 10 days
PRED_DAYS = 10
for i in range(PRED_DAYS):
    pred_i = final_model.predict(last_sequence, verbose=0)
    # Append array1 to array2
    last_sequence = np.concatenate((last_sequence, pred_i[np.newaxis, :, :]), axis=1)
    # Remove the first item
    last_sequence = last_sequence[:, 1:, :]
    
pred_days = scaler.inverse_transform(last_sequence.reshape(PRED_DAYS,4))

df_pred = pd.DataFrame(
    data=pred_days, 
    columns=['Open','High','Low', 'Close'])

df_pred
# Out:
#          Open        High         Low       Close
# 0  120.701300  121.752160  120.556604  120.059511
# 1  120.689100  121.666929  120.506118  120.042918
# 2  120.626904  121.589023  120.445622  119.989456
# 3  120.533628  121.525491  120.410876  119.910296
# 4  120.504456  121.474197  120.303352  119.873316
# 5  120.555862  121.467310  120.148727  119.911379
# 6  120.615052  121.485120  120.058672  119.979831
# 7  120.639861  121.491695  120.065203  120.018658
# 8  120.652811  121.494486  120.102865  120.042175
# 9  120.658369  121.493647  120.132438  120.050153

# %% [markdown]
# <div style="font-family:Georgia; font-size:140%; color: black; text-align:center;">
# <p style="color:black;font-family:Georgia;font-size:140%; text-align:center;">❤️ If you liked it, upvoted, commented and shared. 😉</p>
# ❤️ If you have any questions, feel free to ask. 😉
# </div>
#
# <br><center><img src='https://www.gifcen.com/wp-content/uploads/2021/05/the-end-gif-12.gif' height=80px width=300px></center><br>
